# %%
# imports

import asyncio
import os
import re
from datetime import date

import json
import matplotlib
import neptune.new as neptune
import nest_asyncio
import numpy as np
import pandas as pd
import time

from collections import defaultdict
from itertools import product
from matplotlib import pyplot
from poke_env.environment.abstract_battle import AbstractBattle
from poke_env.player.battle_order import ForfeitBattleOrder
from poke_env.player.player import Player
# from poke_env.player.random_player import RandomPlayer
from scipy.interpolate import griddata
from src.PlayerQLearning import Player as PlayerSarsa

use_neptune = True
if use_neptune:
    run = neptune.init(project='leolellisr/rl-pokeenv',
                       api_token='eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiI1NjY1YmJkZi1hYmM5LTQ3M2QtOGU1ZC1iZTFlNWY4NjE1NDQifQ==',
                       name= 'SarsaDeterministic', tags=['Bruno_', 'SarsaFA', 'Deterministic', 'Train'])
# Out:
# https://app.neptune.ai/leolellisr/rl-pokeenv/e/RLPOK-136
# Remember to stop your run once you’ve finished logging your metadata (https://docs.neptune.ai/api-reference/run#stop). It will be stopped automatically only when the notebook kernel/interactive console is terminated.

# %%
# global configs

debug = True
save_to_json_file = True
use_validation = False

nest_asyncio.apply()
np.random.seed(0)

# %%
# our team

OUR_TEAM = """
Turtonator @ White Herb  
Ability: Shell Armor  
EVs: 4 Atk / 252 SpA / 252 Spe  
Rash Nature  
- Flamethrower  
- Dragon Pulse  
- Earthquake  
- Shell Smash  

Lapras @ Leftovers  
Ability: Shell Armor  
EVs: 252 HP / 252 SpA / 4 SpD  
Modest Nature  
IVs: 0 Atk  
- Freeze-Dry  
- Surf  
- Thunderbolt  
- Toxic  

Armaldo @ Assault Vest  
Ability: Battle Armor  
EVs: 252 HP / 252 Atk / 4 SpD  
Adamant Nature  
- Earthquake  
- Knock Off  
- X-Scissor  
- Aqua Jet  

Drapion @ Life Orb  
Ability: Battle Armor  
EVs: 252 Atk / 4 SpD / 252 Spe  
Jolly Nature  
- Poison Jab  
- Knock Off  
- Earthquake  
- X-Scissor  

Kabutops @ Aguav Berry  
Ability: Battle Armor  
EVs: 252 Atk / 4 SpD / 252 Spe  
Jolly Nature  
- Liquidation  
- Leech Life  
- Knock Off  
- Swords Dance  

Falinks @ Iapapa Berry  
Ability: Battle Armor  
EVs: 252 HP / 252 Atk / 4 SpD  
Adamant Nature  
- Close Combat  
- Poison Jab  
- Iron Head  
- No Retreat  

"""

# %%
# opponent's team

OP_TEAM = """
Cloyster @ Assault Vest  
Ability: Shell Armor  
EVs: 248 HP / 252 Atk / 8 SpA  
Naughty Nature  
- Icicle Spear  
- Surf  
- Tri Attack  
- Poison Jab  

Omastar @ White Herb  
Ability: Shell Armor  
EVs: 252 SpA / 4 SpD / 252 Spe  
Modest Nature  
IVs: 0 Atk  
- Surf  
- Ancient Power  
- Earth Power  
- Shell Smash  

Crustle @ Leftovers  
Ability: Shell Armor  
EVs: 252 HP / 252 Atk / 4 SpD  
Adamant Nature  
- Earthquake  
- Knock Off  
- X-Scissor  
- Stealth Rock  

Escavalier @ Life Orb  
Ability: Shell Armor  
EVs: 248 HP / 252 Atk / 8 SpD  
Adamant Nature  
- Knock Off  
- Swords Dance  
- Iron Head  
- Poison Jab  

Drednaw @ Aguav Berry  
Ability: Shell Armor  
EVs: 248 HP / 252 Atk / 8 SpD  
Adamant Nature  
- Liquidation  
- Earthquake  
- Poison Jab  
- Swords Dance  

Type: Null @ Eviolite  
Ability: Battle Armor  
EVs: 252 HP / 252 Atk / 4 SpD  
Adamant Nature  
- Facade  
- Sleep Talk  
- Shadow Claw  
- Rest  

"""

# %%
N_STATE_COMPONENTS = 12
# num of features = num of state components + action
N_FEATURES = N_STATE_COMPONENTS + 1

N_OUR_MOVE_ACTIONS = 4
N_OUR_SWITCH_ACTIONS = 5
N_OUR_ACTIONS = N_OUR_MOVE_ACTIONS + N_OUR_SWITCH_ACTIONS

ALL_OUR_ACTIONS = np.array(range(0, N_OUR_ACTIONS))

NAME_TO_ID_DICT = {
    "turtonator": 0,
    "lapras": 1,
    "armaldo": 2,
    "drapion": 3,
    "kabutops": 4,
    "falinks": 5,
    "cloyster": 6,
    "omastar": 7,
    "crustle": 8,
    "escavalier": 9,
    "drednaw": 10,
    "typenull": 11
}

# %%
# Max-damage player

class MaxDamagePlayer(Player):
    def choose_move(self, battle):
        if battle.available_moves:
            best_move = max(battle.available_moves, key=lambda move: move.base_power)
            return self.create_order(best_move)
        else:
            return self.choose_random_move(battle)

# %%
# SARSA player

class SARSAFAPlayer(PlayerSarsa):
    def __init__(self, battle_format, team, n0, gamma, lambda_):
        super().__init__(battle_format=battle_format, team=team)
        self.N = defaultdict(lambda: np.zeros(N_OUR_ACTIONS))
        self.F = defaultdict(lambda: np.zeros(N_FEATURES))
        self.e = np.zeros(N_FEATURES)
        self.w = np.random.rand(N_FEATURES)
        self.n0 = n0
        self.gamma = gamma
        self.lambda_ = lambda_
        self.state = None
        self.action = None
        
    def choose_move(self, battle):
        
        if self.state is not None:
            # observe R, next_state and next_action
            reward = self.compute_reward(battle)
            next_state = self.embed_battle(battle)
            next_action = self.policy_fn(next_state, self.w)
            delta = reward
            #alpha
            self.N[str(self.state)][self.action] += 1
            alpha = 0.01 / self.N[str(self.state)][self.action]
            
             #Accumulative
            self.e += 1
            delta = reward + self.gamma * self.q_approx(next_state, next_action, self.w) - self.q_approx(self.state, self.action, self.w)
            
            # update theta
            self.w += alpha * delta * self.e
            
            #update e
            self.e *= self.gamma * self.lambda_
           
            # S <- S'
            self.state = next_state
            # Choose action
            self.action = self.policy_fn(self.state, self.w)
            
        else:
            # S first initialization
            self.state = self.embed_battle(battle)
            self.action = self.policy_fn(self.state, self.w)
        
        # if the selected action is not possible, perform a random move instead
        if self.action == -1:
            return ForfeitBattleOrder()
        elif self.action < 4 and self.action < len(battle.available_moves) and not battle.force_switch:
            return self.create_order(battle.available_moves[self.action])
        elif 0 <= self.action - 4 < len(battle.available_switches):
            return self.create_order(battle.available_switches[self.action - 4])
        else:
            return self.choose_random_move(battle)

    def _battle_finished_callback(self, battle):
        self.e = np.zeros(N_FEATURES)
        if use_neptune: run[f'N0: {self.n0} gamma: {self.gamma} lambda: {self.lambda_} win_acc'].log(self.n_won_battles/len(self._reward_buffer))

    
    ''' Helper functions '''
    
    # feature vector
    @staticmethod
    def x(state, action):
        state = np.array(state).astype(float)
        return np.append(state, action)
    
    # q^(S, A, W)
    def q_approx(self, state, action, w):
        state = np.array(state).astype(float)
        return np.dot(self.x(state, action), w)

    # epsilon-greedy policy
    #Function to choose the next action
    def policy_fn(self, state, w):
        epsilon = self.n0 / (self.n0 + np.sum(self.N[str(state)]))
        # let's get the greedy action. Ties must be broken arbitrarily
        q_approx = np.array([self.q_approx(state, action, w) for action in range(N_OUR_ACTIONS)])
        greedy_action = np.argmax(np.where(q_approx == q_approx.max())[0])
        action_pick_probability = np.full(N_OUR_ACTIONS, epsilon / N_OUR_ACTIONS)
        action_pick_probability[greedy_action] += 1 - epsilon
        return np.random.choice(ALL_OUR_ACTIONS, p=action_pick_probability)
    

    # the embed battle is our state
    # 12 factors: our active mon, opponent's active mon, 4 moves base power, 4 moves multipliers, num fainted mons
    @staticmethod
    def embed_battle(battle):
        # -1 indicates that the move does not have a base power
        # or is not available
        moves_base_power = -np.ones(4)
        moves_dmg_multiplier = np.ones(4)
        for i, move in enumerate(battle.available_moves):
            moves_base_power[i] = (
                    move.base_power / 100
            )  # Simple rescaling to facilitate learning
            if move.type:
                moves_dmg_multiplier[i] = move.type.damage_multiplier(
                    battle.opponent_active_pokemon.type_1,
                    battle.opponent_active_pokemon.type_2,
                )

        # We count how many pokemons have not fainted in each team
        n_fainted_mon_team = (
            len([mon for mon in battle.team.values() if mon.fainted])
        )
        n_fainted_mon_opponent = (
            len([mon for mon in battle.opponent_team.values() if mon.fainted])
        )

        state = list()
        state.append(NAME_TO_ID_DICT[str(battle.active_pokemon).split(' ')[0]])
        state.append(NAME_TO_ID_DICT[str(battle.opponent_active_pokemon).split(' ')[0]])
        for move_base_power in moves_base_power:
            state.append('{0:.2f}'.format(move_base_power))
        for move_dmg_multiplier in moves_dmg_multiplier:
            state.append('{0:.2f}'.format(move_dmg_multiplier))
        state.append(n_fainted_mon_team)
        state.append(n_fainted_mon_opponent)

        return state

    # Computing rewards
    def reward_computing_helper(
            self,
            battle: AbstractBattle,
            *,
            fainted_value: float = 0.15,
            hp_value: float = 0.15,
            number_of_pokemons: int = 6,
            starting_value: float = 0.0,
            status_value: float = 0.15,
            victory_value: float = 1.0
    ) -> float:
        # 1st compute
        if battle not in self._reward_buffer:
            self._reward_buffer[battle] = starting_value
        current_value = 0

        # Verify if pokemon have fainted or have status
        for mon in battle.team.values():
            current_value += mon.current_hp_fraction * hp_value
            if mon.fainted:
                current_value -= fainted_value
            elif mon.status is not None:
                current_value -= status_value

        current_value += (number_of_pokemons - len(battle.team)) * hp_value

        # Verify if opponent pokemon have fainted or have status
        for mon in battle.opponent_team.values():
            current_value -= mon.current_hp_fraction * hp_value
            if mon.fainted:
                current_value += fainted_value
            elif mon.status is not None:
                current_value += status_value

        current_value -= (number_of_pokemons - len(battle.opponent_team)) * hp_value

        # Verify if we won or lost
        if battle.won:
            current_value += victory_value
        elif battle.lost:
            current_value -= victory_value

        # Value to return
        to_return = current_value - self._reward_buffer[battle]
        self._reward_buffer[battle] = current_value
        if use_neptune:
            run[f'N0: {self.n0} gamma: {self.gamma} lambda: {self.lambda_} reward_buffer'].log(current_value)
        return to_return

    # Calling reward_computing_helper
    def compute_reward(self, battle) -> float:
        return self.reward_computing_helper(battle, fainted_value=2, hp_value=1, victory_value=15)

# %%
# sarsa V player

class ValidationPlayer(PlayerSarsa):
    def __init__(self, battle_format, team, w):
        super().__init__(battle_format=battle_format, team=team)
        self.w = w

    def choose_move(self, battle):
        state = self.embed_battle(battle)
        # let's get the greedy action. Ties must be broken arbitrarily
        q_approx = np.array([self.q_approx(state, action, self.w) for action in range(N_OUR_ACTIONS)])
        action = np.argmax(q_approx)
        #action = np.argmax(np.where(q_approx == q_approx.max())[0])

        # if the selected action is not possible, perform a random move instead
        if action == -1:
            return ForfeitBattleOrder()
        elif action < 4 and action < len(battle.available_moves) and not battle.force_switch:
            return self.create_order(battle.available_moves[action])
        elif 0 <= action - 4 < len(battle.available_switches):
            return self.create_order(battle.available_switches[action - 4])
        else:
            return self.choose_random_move(battle)

    def _battle_finished_callback(self, battle):
        pass

    ''' Helper functions '''

    # feature vector
    @staticmethod
    def x(state, action):
        state = np.array(state).astype(float)
        return np.append(state, action)

    # q^(S, A, W)
    def q_approx(self, state, action, w):
        state = np.array(state).astype(float)
        return np.dot(self.x(state, action), w)

    # the embed battle is our state
    # 12 factors: our active mon, opponent's active mon, 4 moves base power, 4 moves multipliers, remaining mons
    @staticmethod
    def embed_battle(battle):
        # -1 indicates that the move does not have a base power
        # or is not available
        moves_base_power = -np.ones(4)
        moves_dmg_multiplier = np.ones(4)
        for i, move in enumerate(battle.available_moves):
            moves_base_power[i] = (
                    move.base_power / 100
            )  # Simple rescaling to facilitate learning
            if move.type:
                moves_dmg_multiplier[i] = move.type.damage_multiplier(
                    battle.opponent_active_pokemon.type_1,
                    battle.opponent_active_pokemon.type_2,
                )

        # We count how many pokemons have not fainted in each team
        fainted_mon_team = (
            len([mon for mon in battle.team.values() if mon.fainted])
        )
        fainted_mon_opponent = (
            len([mon for mon in battle.opponent_team.values() if mon.fainted])
        )

        state = list()
        state.append(NAME_TO_ID_DICT[str(battle.active_pokemon).split(' ')[0]])
        state.append(NAME_TO_ID_DICT[str(battle.opponent_active_pokemon).split(' ')[0]])
        for move_base_power in moves_base_power:
            state.append('{0:.2f}'.format(move_base_power))
        for move_dmg_multiplier in moves_dmg_multiplier:
            state.append('{0:.2f}'.format(move_dmg_multiplier))
        state.append(fainted_mon_team)
        state.append(fainted_mon_opponent)

        return state

# %%
# global parameters

# possible values for num_battles (number of episodes)
n_battles_array = [10000]
# exploration schedule from MC, i. e., epsilon(t) = N0 / (N0 + N(S(t)))
n0_array = [0.0001, 0.001, 0.01]
# possible values for gamma (discount factor)
gamma_array = [0.75] 
#Lambda
lambda_ = [0, 0.2, 0.4, 0.6, 0.8, 1]

list_of_params = [
    {
        'n_battles': n_battles,
        'n0': n0,
        'gamma': gamma,
        'lambda': lambda_
    } for n_battles, n0, gamma, lambda_ in product(n_battles_array, n0_array, gamma_array, lambda_)
]

# %%
# json helper functions
# json helper functions

def save_array_to_json(path_dir, filename, data):
    if not os.path.exists(path_dir):
        os.makedirs(path_dir)
    full_filename = path_dir + "/" + filename
    # write
    with open(full_filename, "w") as file:
        json.dump(data if isinstance(data, list) else data.tolist(), file)
        file.close()


def save_dict_to_json(path_dir, filename, data, append=True):
    if not os.path.exists(path_dir):
        os.makedirs(path_dir)
    full_filename = path_dir + "/" + filename
    if os.path.exists(full_filename) and append:
        with open(full_filename, "r") as file:
            value_dict = json.load(file)
            for key in data:
                value_dict[key] = data[key] if isinstance(data[key], list) else data[key].tolist()
            file.close()
    else:
        value_dict = dict()
        for key in data:
            value_dict[key] = data[key] if isinstance(data[key], list) else data[key].tolist()
    # write
    with open(full_filename, "w") as file:
        json.dump(value_dict, file)
        file.close()


def read_array_from_json(path_dir, filename):
    full_filename = path_dir + "/" + filename
    if not os.path.exists(full_filename):
        return None
    file = open(full_filename, "r")
    data = json.load(file)
    file.close()
    return data


def read_dict_from_json(path_dir, filename):
    full_filename = path_dir + "/" + filename
    if not os.path.exists(full_filename):
        return None
    file = open(full_filename, "r")
    data = json.load(file)
    file.close()
    return data

# %%
# let's battle!
async def lets_battle():
    for params in list_of_params:
        start = time.time()
        if use_neptune:
            run['params'] = params
        params['player'] = SARSAFAPlayer(battle_format="gen8ou", team=OUR_TEAM, n0=params['n0'], gamma=params['gamma'], lambda_= params['lambda'])
        params['opponent'] = MaxDamagePlayer(battle_format="gen8ou", team=OP_TEAM)
        await params['player'].battle_against(opponent=params['opponent'], n_battles=params['n_battles'])
        if debug:
            print("training: num battles (episodes)=%d, N0=%.4f, gamma=%.2f, lambda=%.2f, wins=%d, winning %%=%.2f, total time=%s sec" %
                  (
                      params['n_battles'],
                      round(params['n0'], 4),
                      round(params['gamma'], 2),
                      round(params['lambda'], 4),
                      params['player'].n_won_battles,
                      round((params['player'].n_won_battles / params['n_battles']) * 100, 2),
                      round(time.time() - start, 2)
                  ))

        # save w to json file
        if save_to_json_file:
            today_s = str(date.today())
            n_battle_s = str(params['n_battles'])
            n0_s = str(round(params['n0'], 4))
            gamma_s = str(round(params['gamma'], 4))
            lambda_s = str(round(params['lambda'], 8))
            winning_percentage_s = str(round((params['player'].n_won_battles / params['n_battles']) * 100, 2))
            filename = "WDeterministic" + today_s + "_" + n_battle_s + "_" + n0_s + "_" + gamma_s + "_" + lambda_s + "_" + winning_percentage_s + ".json"
            save_array_to_json("./SarsaDeterministic_FA_w_10k2", filename, params['player'].w)

        # statistics: key: "n_battles, n0, alpha, gamma", values: list of win or lose
        key = str(params['n_battles']) + "_" + str(round(params['n0'], 4)) + "_" + str(round(params['gamma'], 2)) + "_" + str(round(params['lambda'], 2))
        winning_status = list()
        for battle in params['player']._battles.values():
            if battle.won:
                winning_status.append(True)
            else:
                winning_status.append(False)
        # save statistics json file (append)
        data = dict()
        data[key] = winning_status
        save_dict_to_json("./SarsaDeterministic_Learning_FA_statistics2", "statistics.json", data)

# %%
loop = asyncio.get_event_loop()
loop.run_until_complete(loop.create_task(lets_battle()))
# Out:
# training: num battles (episodes)=10000, N0=0.0001, gamma=0.75, lambda=0.00, wins=6060, winning %=60.60, total time=815.82 sec
# training: num battles (episodes)=10000, N0=0.0001, gamma=0.75, lambda=0.20, wins=6145, winning %=61.45, total time=842.16 sec
# training: num battles (episodes)=10000, N0=0.0001, gamma=0.75, lambda=0.40, wins=6136, winning %=61.36, total time=809.54 sec
# training: num battles (episodes)=10000, N0=0.0001, gamma=0.75, lambda=0.60, wins=6003, winning %=60.03, total time=818.81 sec
# training: num battles (episodes)=10000, N0=0.0001, gamma=0.75, lambda=0.80, wins=6032, winning %=60.32, total time=841.55 sec
# training: num battles (episodes)=10000, N0=0.0001, gamma=0.75, lambda=1.00, wins=6035, winning %=60.35, total time=838.9 sec
# 2021-11-08 05:55:59,718 - SARSAFAPlayer 19 - WARNING - Trying to login as SARSAFAPlayer 19, showdown returned  SARSAFAPlayer 19@! - this might prevent future actions from this agent. Changing the agent's username might solve this problem.
# 2021-11-08 05:55:59,722 - SARSAFAPlayer 20 - WARNING - Trying to login as SARSAFAPlayer 20, showdown returned  SARSAFAPlayer 20@! - this might prevent future actions from this agent. Changing the agent's username might solve this problem.
# 2021-11-08 05:55:59,723 - MaxDamagePlayer 38 - WARNING - Trying to login as MaxDamagePlayer 38, showdown returned  MaxDamagePlayer 38@! - this might prevent future actions from this agent. Changing the agent's username might solve this problem.
# 2021-11-08 05:55:59,725 - MaxDamagePlayer 37 - WARNING - Trying to login as MaxDamagePlayer 37, showdown returned  MaxDamagePlayer 37@! - this might prevent future actions from this agent. Changing the agent's username might solve this problem.
# training: num battles (episodes)=10000, N0=0.0010, gamma=0.75, lambda=0.00, wins=6036, winning %=60.36, total time=820.53 sec
# training: num battles (episodes)=10000, N0=0.0010, gamma=0.75, lambda=0.20, wins=6027, winning %=60.27, total time=840.86 sec
# 2021-11-08 06:25:59,720 - MaxDamagePlayer 40 - WARNING - Trying to login as MaxDamagePlayer 40, showdown returned  MaxDamagePlayer 40@! - this might prevent future actions from this agent. Changing the agent's username might solve this problem.
# 2021-11-08 06:25:59,722 - SARSAFAPlayer 22 - WARNING - Trying to login as SARSAFAPlayer 22, showdown returned  SARSAFAPlayer 22@! - this might prevent future actions from this agent. Changing the agent's username might solve this problem.
# 2021-11-08 06:25:59,723 - SARSAFAPlayer 21 - WARNING - Trying to login as SARSAFAPlayer 21, showdown returned  SARSAFAPlayer 21@! - this might prevent future actions from this agent. Changing the agent's username might solve this problem.
# 2021-11-08 06:25:59,723 - MaxDamagePlayer 39 - WARNING - Trying to login as MaxDamagePlayer 39, showdown returned  MaxDamagePlayer 39@! - this might prevent future actions from this agent. Changing the agent's username might solve this problem.
# training: num battles (episodes)=10000, N0=0.0010, gamma=0.75, lambda=0.40, wins=5954, winning %=59.54, total time=842.66 sec
# training: num battles (episodes)=10000, N0=0.0010, gamma=0.75, lambda=0.60, wins=6047, winning %=60.47, total time=839.83 sec
# 2021-11-08 06:55:59,729 - SARSAFAPlayer 23 - WARNING - Trying to login as SARSAFAPlayer 23, showdown returned  SARSAFAPlayer 23@! - this might prevent future actions from this agent. Changing the agent's username might solve this problem.
# 2021-11-08 06:55:59,745 - SARSAFAPlayer 24 - WARNING - Trying to login as SARSAFAPlayer 24, showdown returned  SARSAFAPlayer 24@! - this might prevent future actions from this agent. Changing the agent's username might solve this problem.
# 2021-11-08 06:55:59,747 - MaxDamagePlayer 41 - WARNING - Trying to login as MaxDamagePlayer 41, showdown returned  MaxDamagePlayer 41@! - this might prevent future actions from this agent. Changing the agent's username might solve this problem.
# 2021-11-08 06:55:59,748 - MaxDamagePlayer 42 - WARNING - Trying to login as MaxDamagePlayer 42, showdown returned  MaxDamagePlayer 42@! - this might prevent future actions from this agent. Changing the agent's username might solve this problem.
# training: num battles (episodes)=10000, N0=0.0010, gamma=0.75, lambda=0.80, wins=6046, winning %=60.46, total time=869.52 sec
# Experiencing connection interruptions. Will try to reestablish communication with Neptune. Internal exception was: HTTPServiceUnavailable
# Communication with Neptune restored!
# training: num battles (episodes)=10000, N0=0.0010, gamma=0.75, lambda=1.00, wins=6020, winning %=60.20, total time=872.67 sec
# 2021-11-08 07:25:59,722 - MaxDamagePlayer 43 - WARNING - Trying to login as MaxDamagePlayer 43, showdown returned  MaxDamagePlayer 43@! - this might prevent future actions from this agent. Changing the agent's username might solve this problem.
# 2021-11-08 07:25:59,731 - SARSAFAPlayer 26 - WARNING - Trying to login as SARSAFAPlayer 26, showdown returned  SARSAFAPlayer 26@! - this might prevent future actions from this agent. Changing the agent's username might solve this problem.
# 2021-11-08 07:25:59,733 - SARSAFAPlayer 25 - WARNING - Trying to login as SARSAFAPlayer 25, showdown returned  SARSAFAPlayer 25@! - this might prevent future actions from this agent. Changing the agent's username might solve this problem.
# 2021-11-08 07:25:59,733 - MaxDamagePlayer 44 - WARNING - Trying to login as MaxDamagePlayer 44, showdown returned  MaxDamagePlayer 44@! - this might prevent future actions from this agent. Changing the agent's username might solve this problem.
# training: num battles (episodes)=10000, N0=0.0100, gamma=0.75, lambda=0.00, wins=6017, winning %=60.17, total time=837.78 sec
# training: num battles (episodes)=10000, N0=0.0100, gamma=0.75, lambda=0.20, wins=5969, winning %=59.69, total time=824.23 sec
# training: num battles (episodes)=10000, N0=0.0100, gamma=0.75, lambda=0.40, wins=6042, winning %=60.42, total time=920.72 sec
# 2021-11-08 07:55:59,725 - SARSAFAPlayer 27 - WARNING - Trying to login as SARSAFAPlayer 27, showdown returned  SARSAFAPlayer 27@! - this might prevent future actions from this agent. Changing the agent's username might solve this problem.
# 2021-11-08 07:55:59,730 - SARSAFAPlayer 28 - WARNING - Trying to login as SARSAFAPlayer 28, showdown returned  SARSAFAPlayer 28@! - this might prevent future actions from this agent. Changing the agent's username might solve this problem.
# 2021-11-08 07:55:59,731 - MaxDamagePlayer 46 - WARNING - Trying to login as MaxDamagePlayer 46, showdown returned  MaxDamagePlayer 46@! - this might prevent future actions from this agent. Changing the agent's username might solve this problem.
# 2021-11-08 07:55:59,733 - MaxDamagePlayer 45 - WARNING - Trying to login as MaxDamagePlayer 45, showdown returned  MaxDamagePlayer 45@! - this might prevent future actions from this agent. Changing the agent's username might solve this problem.
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 win_acc. Invalid point: 2021-11-08T10:58:20.820Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 win_acc. Invalid point: 2021-11-08T10:58:20.883Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 win_acc. Invalid point: 2021-11-08T10:58:20.974Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 win_acc. Invalid point: 2021-11-08T10:58:21.053Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 win_acc. Invalid point: 2021-11-08T10:58:21.136Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.823Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.829Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.832Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.838Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.842Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.845Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.849Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.853Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.856Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.859Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.862Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.867Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.870Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.873Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.875Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.880Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.886Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.890Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.893Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.895Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.899Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.903Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.906Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.909Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.914Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.917Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.919Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.923Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.926Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.929Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.934Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.938Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.944Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.948Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.951Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.955Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.959Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.963Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.970Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.978Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.982Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.985Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.987Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.991Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.995Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:20.998Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.002Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.006Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.008Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.012Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.016Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.020Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.024Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.028Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.034Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.037Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.041Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.043Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.046Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.051Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.058Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.062Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.066Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.069Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.072Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.075Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.079Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.082Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.088Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.090Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.093Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.098Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.102Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.104Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.108Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.110Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.113Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.117Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.121Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.124Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.127Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.132Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.140Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.145Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.149Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.152Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.155Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.159Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.162Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.165Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.168Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.172Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.177Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.180Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.184Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.186Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.191Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.194Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.196Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.201Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.205Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.209Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.211Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.216Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.224Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.227Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.230Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.234Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.238Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.242Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.245Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.247Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.252Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.255Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.258Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.260Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.264Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.266Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.269Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.273Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.277Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.281Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.283Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.289Z
# Error occurred during asynchronous operation processing: Timestamp must be non-decreasing for series attribute: N0: 0.01 gamma: 0.75 lambda: 0.6 reward_buffer. Invalid point: 2021-11-08T10:58:21.294Z
# training: num battles (episodes)=10000, N0=0.0100, gamma=0.75, lambda=0.60, wins=6016, winning %=60.16, total time=826.61 sec
# training: num battles (episodes)=10000, N0=0.0100, gamma=0.75, lambda=0.80, wins=6048, winning %=60.48, total time=987.9 sec
# 2021-11-08 08:25:59,722 - SARSAFAPlayer 29 - WARNING - Trying to login as SARSAFAPlayer 29, showdown returned  SARSAFAPlayer 29@! - this might prevent future actions from this agent. Changing the agent's username might solve this problem.
# 2021-11-08 08:25:59,729 - MaxDamagePlayer 48 - WARNING - Trying to login as MaxDamagePlayer 48, showdown returned  MaxDamagePlayer 48@! - this might prevent future actions from this agent. Changing the agent's username might solve this problem.
# 2021-11-08 08:25:59,732 - SARSAFAPlayer 30 - WARNING - Trying to login as SARSAFAPlayer 30, showdown returned  SARSAFAPlayer 30@! - this might prevent future actions from this agent. Changing the agent's username might solve this problem.
# 2021-11-08 08:25:59,733 - MaxDamagePlayer 47 - WARNING - Trying to login as MaxDamagePlayer 47, showdown returned  MaxDamagePlayer 47@! - this might prevent future actions from this agent. Changing the agent's username might solve this problem.
# training: num battles (episodes)=10000, N0=0.0100, gamma=0.75, lambda=1.00, wins=5959, winning %=59.59, total time=852.11 sec
# Experiencing connection interruptions. Will try to reestablish communication with Neptune. Internal exception was: RequestsFutureAdapterConnectionError
# Experiencing connection interruptions. Will try to reestablish communication with Neptune. Internal exception was: RequestsFutureAdapterConnectionError
# Experiencing connection interruptions. Will try to reestablish communication with Neptune. Internal exception was: RequestsFutureAdapterConnectionError

# %%
if use_neptune: run.stop()
# Out:
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 5 operations to synchronize with Neptune. Do not kill this process.
# All 5 operations synced, thanks for waiting!

# %%
# plotting helper functions

def plot_2d(path, title, x_label, x_array, y_label, y_array):
    # print("plotting %s" % title)
    # set labels and plot surface
    figure = matplotlib.pyplot.figure(figsize=(20, 10))
    ax = figure.gca()
    ax.set_title(title)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    ax.plot(x_array, y_array)
    # pyplot.show()
    if not os.path.exists(path):
        os.makedirs(path)
    filename = path + "/" + title + "_" + x_label + "_" + y_label + "_" + ".pdf"
    figure.savefig(filename, dpi=figure.dpi)
    pyplot.close(figure)
    # print("done!")


def plot_3d(path, title, x_label, x_array, y_label, y_array, z_label, z_array):
    # print("plotting %s" % title)
    xyz = {'x': x_array, 'y': y_array, 'z': z_array}
    df = pd.DataFrame(xyz, index=range(len(xyz['x'])))
    xv, yv = np.meshgrid(x_array, y_array)
    zv = griddata((df['x'], df['y']), df['z'], (xv, yv), method='nearest')
    # set labels and plot surface
    figure = matplotlib.pyplot.figure(figsize=(20, 10))
    ax = figure.gca(projection='3d')
    ax.set_title(title)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    ax.set_zlabel(z_label)
    surface = ax.plot_surface(xv, yv, zv, rstride=1, cstride=1, cmap=matplotlib.cm.coolwarm, linewidth=0,
                              antialiased=False)
    figure.colorbar(surface)
    # pyplot.show()
    if not os.path.exists(path):
        os.makedirs(path)
    filename = path + "/" + title + ".pdf"
    figure.savefig(filename, dpi=figure.dpi)
    pyplot.close(figure)
    # print("done!")

# %%
# plot additional statistics

def plot_statistics_json(path_dir, filename="statistics.json"):
    # plots from statistics.json
    statistics = read_dict_from_json(path_dir, filename)
    # win/lost vs. episode number
    for key in statistics.keys():
        key_elements = key.split("_")
        n_battles = key_elements[0]
        n0 = key_elements[1]
        alpha = key_elements[2]
        gamma = key_elements[3]
        value = statistics[key]
        plot_2d(path="./SarsaDeterministic_Learning_FA_plot",
                title="acc_victories_n_battles_" + n_battles + "_N0_" + n0 + "_alpha_" + alpha + "_gamma_" + gamma,
                x_label="episodes",
                x_array=np.array(range(0, len(value))),
                y_label="acc victory",
                y_array=np.cumsum(value).astype(np.int))

    # winning % by set of parameters
    n_battles = ""
    alpha = ""
    x_values = []
    y_values = []
    z_values = []
    for key in statistics.keys():
        key_elements = key.split("_")
        n_battles = key_elements[0]
        n0 = key_elements[1]
        alpha = key_elements[2]
        gamma = key_elements[3]
        value = statistics[key]
        x_values.append(n0)
        y_values.append(gamma)
        z_values.append(value.count(True) / len(value))
    plot_3d(path="./SarsaDeterministic_Learning_FA_plot",
            title="winning_percentage_n_battles_" + n_battles + "_alpha_" + alpha,
            x_label="N0",
            x_array=np.array(x_values).astype(np.float),
            y_label="gamma",
            y_array=np.array(y_values).astype(np.float),
            z_label="winning %",
            z_array=np.array(z_values))


# plots from statistics
plot_statistics_json("./SarsaDeterministic_Learning_FA_statistics")

# %%
# validation max player

async def do_battle_validation(path_dir):
    # read from json
    for filename in os.listdir(path_dir):
        # learned feature vector
        w = np.array(read_array_from_json(path_dir, filename))
        # params: n_battles, n0, gamma
        params = filename.split("_")
        n_battles = int(params[1])
        n0 = float(params[2])
        gamma = float(params[3])
        lambda_ = float(params[4])

        # validation (play 1/3 of the battles using Q-learned table)
        start = time.time()
        validation_player = ValidationPlayer(battle_format="gen8ou", team=OUR_TEAM, w=w)
        opponent = MaxDamagePlayer(battle_format="gen8ou", team=OP_TEAM)
        n_battles_validation = int(n_battles / 3)
        await validation_player.battle_against(opponent=opponent, n_battles=n_battles_validation)
        print("validation: num battles (episodes)=%d, N0=%.4f, gamma=%.2f, lambda=%.2f, wins=%d, winning %%=%.2f, total time=%s sec" %
              (
                  n_battles_validation,
                  n0,
                  gamma,
                  lambda_,
                  validation_player.n_won_battles,
                  round((validation_player.n_won_battles / n_battles_validation) * 100, 2),
                  round(time.time() - start, 2)
              ))

# %%
loop = asyncio.get_event_loop()
loop.run_until_complete(loop.create_task(do_battle_validation("./SarsaDeterministic_FA_w_10k")))

# %%
from poke_env.player.player import Player
from poke_env.player.random_player import RandomPlayer

randomPlayer = RandomPlayer(battle_format="gen8ou", team=OUR_TEAM)

# %%
# validation random player

async def do_battle_validation(path_dir):
    # read from json
    for filename in os.listdir(path_dir):
        # learned feature vector
        w = np.array(read_array_from_json(path_dir, filename))
        # params: n_battles, n0, gamma
        params = filename.split("_")
        n_battles = int(params[1])
        n0 = float(params[2])
        gamma = float(params[3])
        lambda_ = float(params[4])

        # validation (play 1/3 of the battles using Q-learned table)
        start = time.time()
        validation_player = ValidationPlayer(battle_format="gen8ou", team=OUR_TEAM, w=w)
        opponent = RandomPlayer(battle_format="gen8ou", team=OUR_TEAM)
        n_battles_validation = int(n_battles / 3)
        await validation_player.battle_against(opponent=opponent, n_battles=n_battles_validation)
        print("validation: num battles (episodes)=%d, N0=%.4f, gamma=%.2f, lambda=%.2f, wins=%d, winning %%=%.2f, total time=%s sec" %
              (
                  n_battles_validation,
                  n0,
                  gamma,
                  lambda_,
                  validation_player.n_won_battles,
                  round((validation_player.n_won_battles / n_battles_validation) * 100, 2),
                  round(time.time() - start, 2)
              ))

# %%
loop = asyncio.get_event_loop()
loop.run_until_complete(loop.create_task(do_battle_validation("./SarsaDeterministic_FA_w_10k")))
